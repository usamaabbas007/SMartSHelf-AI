# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/sales_data.csv')
df.groupby('Category')['Revenue_LastQuarter'].sum().plot(kind='bar')
plt.title('Revenue by Category')
plt.show()
